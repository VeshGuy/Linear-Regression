# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = 6 * np.random.rand(100, 1) - 3
y = 0.5 * x**2 + 1.5*x + 2 + np.random.randn(100, 1)
# Quadratic Equation used -> y = 0.5x^2 + 1.5x + 2 + outliers
plt.scatter(x, y, color='g')
plt.xlabel("X Dataset")
plt.ylabel("Y Dataset")
# Out:
# Text(0, 0.5, 'Y Dataset')

# %% [markdown]
# **The dataset doesn't have linear datapoints, it is non-linear**
#
# **So if try Linear Regression, the best fit line won't reach every data point**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
y_train.shape
# Out:
# (80, 1)

# %%
# Simplee Linear Regression
from sklearn.linear_model import LinearRegression
regression1 = LinearRegression()

# %%
regression1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, regression1.predict(x_test))
print(score)
# Out:
# 0.7995959757915012

# %%
plt.plot(x_train, regression1.predict(x_train), color='r')
plt.scatter(x_train, y_train)
plt.xlabel("X Dataset")
plt.ylabel("Y Dataset")
# Out:
# Text(0, 0.5, 'Y Dataset')

# %% [markdown]
# Using Linear Regression for non-Linear data points, shows that the best fit line barely touches any data points

# %% [markdown]
# ## Now using Polynomial Regression

# %%
# LEt's apply polynomial transformation
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2, include_bias=True)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# %%
x_train_poly
# [Bias, x1, x^2]
# Out:
# array([[ 1.00000000e+00,  1.11003014e+00,  1.23216691e+00],
#        [ 1.00000000e+00, -6.22014926e-01,  3.86902568e-01],
#        [ 1.00000000e+00,  1.88957653e+00,  3.57049946e+00],
#        [ 1.00000000e+00,  5.00312435e-01,  2.50312533e-01],
#        [ 1.00000000e+00,  1.67470587e-01,  2.80463977e-02],
#        [ 1.00000000e+00, -9.68702797e-01,  9.38385110e-01],
#        [ 1.00000000e+00,  2.82755965e+00,  7.99509357e+00],
#        [ 1.00000000e+00,  2.17618983e+00,  4.73580219e+00],
#        [ 1.00000000e+00,  6.89625511e-01,  4.75583345e-01],
#        [ 1.00000000e+00,  2.58809331e+00,  6.69822697e+00],
#        [ 1.00000000e+00, -1.45683761e+00,  2.12237581e+00],
#        [ 1.00000000e+00,  1.40743084e+00,  1.98086156e+00],
#        [ 1.00000000e+00, -1.47672836e+00,  2.18072664e+00],
#        [ 1.00000000e+00,  2.68601231e+00,  7.21466214e+00],
#        [ 1.00000000e+00,  5.31671858e-01,  2.82674964e-01],
#        [ 1.00000000e+00, -2.58309493e+00,  6.67237940e+00],
# ...

# %%
from sklearn.metrics import r2_score
regression = LinearRegression()
regression.fit(x_train_poly, y_train)
y_pred = regression.predict(x_test_poly)
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.8741392347013126

# %% [markdown]
# When **Polynomial Regression is used Accuracy is 89%**, compared to **62% of Linear Regression**

# %%
plt.scatter(x_train, regression.predict(x_train_poly))
plt.scatter(x_train, y_train)

# %%
# Prediction of new data
x_new = np.linspace(-3, 3, 200).reshape(200, 1)
x_new_poly = poly.transform(x_new)
x_new_poly
# Out:
# array([[ 1.00000000e+00, -3.00000000e+00,  9.00000000e+00],
#        [ 1.00000000e+00, -2.96984925e+00,  8.82000455e+00],
#        [ 1.00000000e+00, -2.93969849e+00,  8.64182723e+00],
#        [ 1.00000000e+00, -2.90954774e+00,  8.46546804e+00],
#        [ 1.00000000e+00, -2.87939698e+00,  8.29092700e+00],
#        [ 1.00000000e+00, -2.84924623e+00,  8.11820409e+00],
#        [ 1.00000000e+00, -2.81909548e+00,  7.94729931e+00],
#        [ 1.00000000e+00, -2.78894472e+00,  7.77821267e+00],
#        [ 1.00000000e+00, -2.75879397e+00,  7.61094417e+00],
#        [ 1.00000000e+00, -2.72864322e+00,  7.44549380e+00],
#        [ 1.00000000e+00, -2.69849246e+00,  7.28186157e+00],
#        [ 1.00000000e+00, -2.66834171e+00,  7.12004747e+00],
#        [ 1.00000000e+00, -2.63819095e+00,  6.96005151e+00],
#        [ 1.00000000e+00, -2.60804020e+00,  6.80187369e+00],
#        [ 1.00000000e+00, -2.57788945e+00,  6.64551400e+00],
#        [ 1.00000000e+00, -2.54773869e+00,  6.49097245e+00],
# ...

# %%
y_new = regression.predict(x_new_poly)
plt.plot(x_new, y_new, "r-", linewidth=2, label="New Predictions")
plt.plot(x_train, y_train, "b.", label="Testing points")
plt.plot(x_test, y_test, "g.", label='Testing Points')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
from sklearn.pipeline import Pipeline

# %%
import numpy as np

# %%
def poly_regression(degree):
    x_new = np.linspace(-3, 3, 200).reshape(200, 1)
    poly_features = PolynomialFeatures(degree=degree, include_bias=True)
    lin_reg = LinearRegression()
    poly_regression = Pipeline([
        ("Poly features", poly_features),
        ("lin_reg", lin_reg)
    ])
    poly_regression.fit(x_train, y_train)   # Polynomial and fit of Linear regression
    y_pred_new = poly_regression.predict(x_new)
    # Pllotting prediction line
    plt.plot(x_new, y_pred_new, 'r', label='Degree '+ str(degree), linewidth=2)
    plt.plot(x_train, y_train, "b.", linewidth=3)
    plt.plot(x_test, y_test, "g.", linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.axis([-4, 4, 0, 10])
    plt.show()

# %%
poly_regression(6)

# %% [markdown]
# If we make the input 10 or above, it will start to overfit the model.
#
# Hence, 6 is fair enough
